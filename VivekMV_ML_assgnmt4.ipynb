# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')

# %%
a=df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
np.max(df)
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %%
a=sns.pairplot(df,hue='species',palette="muted",size=5,vars=['sepal_width','sepal_length','petal_length','petal_width'],kind='scatter')
# Out:
# c:\python39\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
v=sns.violinplot(x='species',y='sepal_width',data=df)

# %%
i=sns.boxplot(y=df['sepal_length'])
